# %% [markdown]
# <a href="https://colab.research.google.com/github/kity2233466/FINAL/blob/%E6%B8%AC%E8%A9%A6%E5%87%BA%E7%89%88/%E6%8F%9B%E8%87%89AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 進入工作區並清理舊檔
# %cd /content
# !rm -rf roop
# !git clone https://github.com/s0md3v/roop.git
# %cd roop

# 2. 下載你在 GitHub 倉庫裡寫好的正確補丁
# !wget -O fix_roop.py https://raw.githubusercontent.com/kity2233466/roop-colab-fix/main/fix_roop.py

# 3. 安裝 2025 相容性依賴 (鎖定 Numpy 版本)
# !pip install -q "numpy<2.0" onnxruntime-gpu==1.17.1 insightface==0.7.3 opencv-python-headless==4.9.0.80 customtkinter tkinterdnd2 opennsfw2

# 4. 下載核心 AI 模型檔
# !mkdir -p models
# !wget -q --show-progress -O models/inswapper_128.onnx "https://huggingface.co/ezioruan/inswapper_128.onnx/resolve/main/inswapper_128.onnx"

print("\n✅ 第一步完成：環境與你的專屬補丁已就緒。")
# Out:
# /content
# Cloning into 'roop'...
# remote: Enumerating objects: 1540, done.
# remote: Total 1540 (delta 0), reused 0 (delta 0), pack-reused 1540 (from 1)
# Receiving objects: 100% (1540/1540), 97.45 MiB | 12.80 MiB/s, done.
# Resolving deltas: 100% (904/904), done.
# /content/roop
# --2025-12-24 03:23:55--  https://raw.githubusercontent.com/kity2233466/roop-colab-fix/main/fix_roop.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1127 (1.1K) [text/plain]
# Saving to: ‘fix_roop.py’
#
# fix_roop.py         100%[===================>]   1.10K  --.-KB/s    in 0s
#
# 2025-12-24 03:23:55 (91.0 MB/s) - ‘fix_roop.py’ saved [1127/1127]
#
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %%
import os
import numpy as np

# 1. 補回 2025 環境缺失的 Numpy 屬性
np.int = int
np.float = float
np.bool = bool

# 2. 執行你在倉庫裡寫的修復腳本 (修正核心代碼與縮排)
# %cd /content/roop
# !python fix_roop.py

print("✅ 第二步完成：你的 GitHub 補丁已成功套用到系統核心。")
# Out:
# /content/roop
# ✅ core.py 修復完成
# ✅ face_swapper.py 修復完成
# ✅ 第二步完成：你的 GitHub 補丁已成功套用到系統核心。

# %%
# %cd /content/roop

# 啟動換臉任務 (請確保 face.jpg 和 video.mp4 已上傳)
# !python run.py \
    --source /content/face.jpg \
    --target /content/video.mp4 \
    --output /content/result.mp4 \
    --execution-provider cuda \
    --frame-processor face_swapper

print("\n🎉 處理完成！請在 /content/ 下載成品。")
# Out:
# /content/roop
# 2025-12-24 03:25:38.179992: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766546738.200117    3216 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766546738.205531    3216 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766546738.219692    3216 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
